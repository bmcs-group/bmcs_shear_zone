# %% [markdown]
# # DIC file timeline

# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import numpy as np
import re

# %%
import sz_tests_series_2023 as ts
dcl = ts.new_dclx(ts.B6_TV2)

# %%
dp = dcl.dsf.dic_grid.dic_inp

# %%
dic_grid = dcl.dsf.dic_grid
dic_grid.t_T

# %%
dp.F_dsc_cutoff_fraction = 0.97

# %%
from numpy import size


fig, ax = plt.subplots(1,1)
dp.plot_load_deflection(ax)

# %%
dic_grid.F_T_t
