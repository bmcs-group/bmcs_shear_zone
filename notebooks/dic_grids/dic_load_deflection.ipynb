# %% [markdown]
# # Load Deflection Curves

# %%
# %matplotlib widget

# %%
from bmcs_shear.dic_crack import DICGrid, DICAlignedGrid, DICCOR, DICInspector, DICCrack

# %% [markdown]
# # B1_TV1

# %%
dic_grid = DICGrid(dir_name = 'B1_TV1')

# %%
dic_grid.ld_data_dir
# Out:
# 'C:\\Users\\fahad\\simdb\\data\\shear_zone\\B1_TV1\\load_deflection'

# %%
dic_grid = DICGrid(n_x=59, n_y=15, d_x=22, d_y=22,
                   start_t=0, end_t=-1, U_factor=100, dir_name='B1_TV1', grid_column_first=False, 
                   grid_number_vertical=False)
dic_aligned_grid = DICAlignedGrid(dic_grid=dic_grid,
                                 y_ref_i=-20, y_ref_j_min=1, y_ref_j_max=10)
dic_cor = DICCOR(dic_aligned_grid=dic_aligned_grid,
                 n_x_min=29, n_x_max=37, n_x_step=1, n_y_min=7, n_y_step=1)
dic_grid.interact()

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B1_TV2

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B1_TV2')

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B5_TV1

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B5_TV1')

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B5_TV2

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B5_TV2')

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B6_TV1

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B6_TV1')

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B6_TV2

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B6_TV2')

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B7_TV1

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B7_TV1')

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B7_TV2

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B7_TV2')

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B8_TV1

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B8_TV1')

# %%
dic_load_deflection.interact()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23188/1196940294.py in <module>
# ----> 1 dic_load_deflection.interact()
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\bmcs_utils\model.py in interact(self, **kw)
#      43
#      44     def interact(self,**kw):
# ---> 45         return AppWindow(self,**kw).interact()
#      46
#      47     def app(self,**kw):
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\bmcs_utils\app_window.py in interact(self)
#     133                              layout=ipw.Layout(align_items="stretch",
#     134                                                width="100%"))
# --> 135         self.model_tree.selected = True
#     136         display(app_print)
#     137
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
# ...

# %% [markdown]
# # B8_TV2

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B8_TV2')

# %%
dic_load_deflection.interact()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23188/1196940294.py in <module>
# ----> 1 dic_load_deflection.interact()
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\bmcs_utils\model.py in interact(self, **kw)
#      43
#      44     def interact(self,**kw):
# ---> 45         return AppWindow(self,**kw).interact()
#      46
#      47     def app(self,**kw):
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\bmcs_utils\app_window.py in interact(self)
#     133                              layout=ipw.Layout(align_items="stretch",
#     134                                                width="100%"))
# --> 135         self.model_tree.selected = True
#     136         display(app_print)
#     137
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
# ...

# %% [markdown]
# # B9_TV1

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B9_TV1')

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B9_TV2

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B9_TV2')

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B10_TV1

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B10_TV1')

# %%
dic_load_deflection.interact()

# %% [markdown]
# # B10_TV2

# %%
dic_load_deflection = DICLoadDeflection(dir_name = 'B10_TV2')

# %%
dic_load_deflection.interact()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23188/1196940294.py in <module>
# ----> 1 dic_load_deflection.interact()
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\bmcs_utils\model.py in interact(self, **kw)
#      43
#      44     def interact(self,**kw):
# ---> 45         return AppWindow(self,**kw).interact()
#      46
#      47     def app(self,**kw):
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\bmcs_utils\app_window.py in interact(self)
#     133                              layout=ipw.Layout(align_items="stretch",
#     134                                                width="100%"))
# --> 135         self.model_tree.selected = True
#     136         display(app_print)
#     137
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
# ...
