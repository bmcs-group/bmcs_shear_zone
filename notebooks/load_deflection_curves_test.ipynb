# %%
import sympy as sp
import numpy as np
from os.path import join, expanduser
import os
import traits.api as tr

# %%
home_dir = expanduser('~')
data_dir = join(home_dir,'simdb','data','load_deflection')
data_dir
# Out:
# 'C:\\Users\\fahad\\simdb\\data\\load_deflection'

# %%
results = [join(data_dir,each) 
           for each in sorted(os.listdir(data_dir)) 
           if each.endswith('.txt')]
results
# Out:
# ['C:\\Users\\fahad\\simdb\\data\\load_deflection\\B1_TV1 (L-D).txt',
#  'C:\\Users\\fahad\\simdb\\data\\load_deflection\\B1_TV1.txt']

# %%
np.loadtxt(results[0], dtype=float, 
            skiprows=1, usecols=(1,2), unpack=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-53016dba8920> in <module>
# ----> 1 np.loadtxt(results[0], dtype=float,
#       2             skiprows=1, usecols=(1,2), unpack=False)
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1144         # converting the data
#    1145         X = None
# -> 1146         for x in read_data(_loadtxt_chunksize):
#    1147             if X is None:
#    1148                 X = np.array(x, dtype)
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\numpy\lib\npyio.py in read_data(chunk_size)
#     995
#     996             # Convert each value according to its column and store
# --> 997             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     998
# ...

# %%
f = open("C:\\Users\\fahad\\simdb\\data\\load_deflection\B1_TV1.txt", "r")
print(f.read())
# Out:
# Zeit  1 - Langsame Messrate [s]	Kraft [kN]	WD-3 [mm]
# 0	"0,1363"	"0,00052"
# "0,1000"	"0,1364"	"0,00053"
# "0,2000"	"0,1374"	"0,00053"
# "0,3000"	"0,1372"	"0,00055"
# "0,4000"	"0,1372"	"0,00053"
# "0,5000"	"0,1372"	"0,00052"
# "0,6000"	"0,1362"	"0,00058"
# "0,7000"	"0,1353"	"0,00056"
# "0,8000"	"0,1340"	"0,00056"
# "0,9000"	"0,1341"	"0,00055"
# "1,000"	"0,1336"	"0,00056"
# "1,100"	"0,1336"	"0,00052"
# "1,200"	"0,1339"	"0,00053"
# "1,300"	"0,1337"	"0,00054"
# "1,400"	"0,1336"	"0,00052"
# "1,500"	"0,1336"	"0,00055"
# "1,600"	"0,1341"	"0,00060"
# "1,700"	"0,1346"	"0,00060"
# "1,800"	"0,1344"	"0,00050"
# "1,900"	"0,1344"	"0,00053"
# "2,000"	"0,1339"	"0,00051"
# "2,100"	"0,1338"	"0,00054"
# "2,200"	"0,1338"	"0,00081"
# "2,300"	"0,1339"	"0,00101"
# "2,400"	"0,1334"	"0,00077"
# "2,500"	"0,1331"	"0,00091"
# "2,600"	"0,1334"	"0,00100"
# "2,700"	"0,1334"	"0,00088"
# "2,800"	"0,1334"	"0,00107"
# "2,900"	"0,1334"	"0,00092"
# "3,000"	"0,1333"	"0,00096"
# "3,100"	"0,1334"	"0,00097"
# ...
