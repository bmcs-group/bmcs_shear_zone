# %%
from bmcs_shear.dic_crack import DICGrid, DICAlignedGrid, DICCOR, DICInspector, DICCrack, DICLoadRotation

# %% [markdown]
# # B1_TV1

# %%
dic_grid = DICGrid(n_x=58, n_y=15, d_x=22, d_y=22, 
                   start_t=0, end_t=30, U_factor=1, dir_name='B1_TV1')
dic_aligned_grid = DICAlignedGrid(dic_grid=dic_grid,
                                  y_ref_i=-17, y_ref_j_min=1, y_ref_j_max=10)
dic_cor = DICCOR(dic_aligned_grid=dic_aligned_grid,
                 n_x_min=29, n_x_max=38, n_x_step=1, n_y_min=4, n_y_step=1)
dic_load_rotation = DICLoadRotation(dic_grid = dic_grid, dic_cor=dic_cor, dic_aligned_grid=dic_aligned_grid)

# %%
dic_load_rotation.dic_grid.end_t
# Out:
# 30

# %%
dic_load_rotation.phi
# Out:
# evaluating step 1
# Exception occurred in traits notification handler for object: <bmcs_shear.dic_crack.dic_grid.DICGrid object at 0x000002A0E09306D0>, trait: state_changed, old value: <undefined>, new value: True
# Traceback (most recent call last):
#   File "C:\Users\fahad\Anaconda3\envs\bmcs_env\lib\site-packages\traits\trait_notifiers.py", line 524, in _dispatch_change_event
#     self.dispatch(handler, *args)
#   File "C:\Users\fahad\Anaconda3\envs\bmcs_env\lib\site-packages\traits\trait_notifiers.py", line 486, in dispatch
#     handler(*args)
#   File "C:\Users\fahad\Anaconda3\envs\bmcs_env\lib\site-packages\traits\has_traits.py", line 1032, in wrapper0
#     return function(arg)
#   File "C:\Users\fahad\Anaconda3\envs\bmcs_env\lib\site-packages\traits\has_traits.py", line 3428, in notify
#     self.trait_property_changed(name, old)
#   File "C:\Users\fahad\Anaconda3\envs\bmcs_env\lib\site-packages\traits\has_traits.py", line 960, in decorator
# ...

# %%
dic_load_rotation.interact()
# Out:
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15832/2936248321.py in <module>
# ----> 1 dic_load_rotation.interact()
#
# c:\users\fahad\pycharmprojects\bmcs_utils\bmcs_utils\model.py in interact(self, **kw)
#      43
#      44     def interact(self,**kw):
# ---> 45         return AppWindow(self,**kw).interact()
#      46
#      47     def app(self,**kw):
#
# c:\users\fahad\pycharmprojects\bmcs_utils\bmcs_utils\app_window.py in interact(self)
#     149                              layout=ipw.Layout(align_items="stretch",
#     150                                                width="100%"))
# --> 151         self.model_tree.selected = True
#     152         display(app_print)
#     153
#
# ~\Anaconda3\envs\bmcs_env\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
# ...
