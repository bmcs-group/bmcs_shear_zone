# %%
import bmcs_utils.api as bu
from bmcs_shear_zone.shear_crack.crack_tip_rotation import \
    SZCrackTipRotation

sz_mechanism_ict = bu.InteractiveWindow(SZCrackTipRotation(), figsize=(7, 3))
sz_mechanism_ict.fig.tight_layout = True
sz_mechanism_ict.interact()
